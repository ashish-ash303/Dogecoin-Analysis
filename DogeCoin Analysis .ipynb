# %% [markdown]
# ## Exploratry Data Analysis of  DogeCoin  Using Pandas,Numpy and Matplotlib

# %% [markdown]
# # Q. What is Dogecoin?

# %% [markdown]
# * Dogecoin is a cryptocurrency created by software engineers Billy Markus and Jackson Palmer, who decided to create a payment system as a joke, making fun of the wild speculation in cryptocurrencies at the time. Despite its satirical nature, some consider it a legitimate investment prospect.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Dataset:-https://www.kaggle.com/dhruvildave/dogecoin-historical-data

# %% [markdown]
# * We Start Analysing The Data by Importing the Following Library

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
doge_df=pd.read_csv('DOGE-USD.csv')
doge_df
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2014-09-17  0.000293  0.000299  0.000260  0.000268   0.000268
# 1     2014-09-18  0.000268  0.000325  0.000267  0.000298   0.000298
# 2     2014-09-19  0.000298  0.000307  0.000275  0.000277   0.000277
# 3     2014-09-20  0.000276  0.000310  0.000267  0.000292   0.000292
# 4     2014-09-21  0.000293  0.000299  0.000284  0.000288   0.000288
# ...          ...       ...       ...       ...       ...        ...
# 2449  2021-06-01  0.325744  0.383079  0.312360  0.370077   0.370077
# 2450  2021-06-02  0.370302  0.444590  0.352588  0.423374   0.423374
# 2451  2021-06-03  0.423739  0.440763  0.378819  0.399963   0.399963
# 2452  2021-06-04  0.400982  0.400982  0.351442  0.376323   0.376323
# 2453  2021-06-05  0.373712  0.389095  0.373712  0.383337   0.383337
#
#             Volume
# 0     1.463600e+06
# 1     2.215910e+06
# 2     8.835630e+05
# 3     9.930040e+05
# 4     5.391400e+05
# ...            ...
# ...

# %% [markdown]
# # We Have total 2454 rows ans 7 Columns

# %%
doge_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
doge_df.drop(['Adj Close','Volume'],axis=1)
# Out:
#             Date      Open      High       Low     Close
# 0     2014-09-17  0.000293  0.000299  0.000260  0.000268
# 1     2014-09-18  0.000268  0.000325  0.000267  0.000298
# 2     2014-09-19  0.000298  0.000307  0.000275  0.000277
# 3     2014-09-20  0.000276  0.000310  0.000267  0.000292
# 4     2014-09-21  0.000293  0.000299  0.000284  0.000288
# ...          ...       ...       ...       ...       ...
# 2449  2021-06-01  0.325744  0.383079  0.312360  0.370077
# 2450  2021-06-02  0.370302  0.444590  0.352588  0.423374
# 2451  2021-06-03  0.423739  0.440763  0.378819  0.399963
# 2452  2021-06-04  0.400982  0.400982  0.351442  0.376323
# 2453  2021-06-05  0.373712  0.389095  0.373712  0.383337
#
# [2454 rows x 5 columns]

# %% [markdown]
# * After droping the Unneccessary Column we have now 2454 rows and 5 columns

# %%
plt.figure(figsize = (20,10))
doge_df.groupby('Date')['Open'].mean().plot(marker='o',ls='-',lw=3,ms=3,mew=1,alpha=.5);
plt.xlabel('Date');
plt.ylabel('Volume');

# %% [markdown]
# # Its Hard to Get any information Clearly From this Visulation So We take data part by part To Visulize it More Clearly

# %% [markdown]
# * We First Start With Checking the Trend Of Dogecoin in First 15  Days

# %%
doge_df_top=doge_df.head(15)
doge_df_top
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume
# 0   2014-09-17  0.000293  0.000299  0.000260  0.000268   0.000268  1463600.0
# 1   2014-09-18  0.000268  0.000325  0.000267  0.000298   0.000298  2215910.0
# 2   2014-09-19  0.000298  0.000307  0.000275  0.000277   0.000277   883563.0
# 3   2014-09-20  0.000276  0.000310  0.000267  0.000292   0.000292   993004.0
# 4   2014-09-21  0.000293  0.000299  0.000284  0.000288   0.000288   539140.0
# 5   2014-09-22  0.000288  0.000301  0.000285  0.000298   0.000298   620222.0
# 6   2014-09-23  0.000298  0.000318  0.000295  0.000313   0.000313   739197.0
# 7   2014-09-24  0.000314  0.000353  0.000310  0.000348   0.000348  1277840.0
# 8   2014-09-25  0.000347  0.000383  0.000332  0.000375   0.000375  2393610.0
# 9   2014-09-26  0.000374  0.000467  0.000373  0.000451   0.000451  4722610.0
# 10  2014-09-27  0.000450  0.000452  0.000359  0.000375   0.000375  2907080.0
# ...

# %%
doge_df_top.drop(['Adj Close','Volume'],axis=1)
# Out:
#           Date      Open      High       Low     Close
# 0   2014-09-17  0.000293  0.000299  0.000260  0.000268
# 1   2014-09-18  0.000268  0.000325  0.000267  0.000298
# 2   2014-09-19  0.000298  0.000307  0.000275  0.000277
# 3   2014-09-20  0.000276  0.000310  0.000267  0.000292
# 4   2014-09-21  0.000293  0.000299  0.000284  0.000288
# 5   2014-09-22  0.000288  0.000301  0.000285  0.000298
# 6   2014-09-23  0.000298  0.000318  0.000295  0.000313
# 7   2014-09-24  0.000314  0.000353  0.000310  0.000348
# 8   2014-09-25  0.000347  0.000383  0.000332  0.000375
# 9   2014-09-26  0.000374  0.000467  0.000373  0.000451
# 10  2014-09-27  0.000450  0.000452  0.000359  0.000375
# 11  2014-09-28  0.000376  0.000414  0.000376  0.000392
# 12  2014-09-29  0.000394  0.000401  0.000378  0.000396
# 13  2014-09-30  0.000397  0.000408  0.000386  0.000399
# 14  2014-10-01  0.000400  0.000406  0.000371  0.000371

# %%
plt.figure(figsize=(20,12))
plt.plot(doge_df_top.Date,doge_df_top.Open,marker='s',c='b',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Opening Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['Open','Date']);

# %% [markdown]
# The highest Opening Of the DogeCoin Was On 2014-09-27 With the Value of Over 0.000450 in  the Data of first 15 days

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.plot(doge_df_top.Date,doge_df_top.Close,marker='s',c='g',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('Close',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Closing Market",fontsize=30, pad=20);
plt.legend(['Close','Date']);

# %% [markdown]
# * The highest Closing Of the DogeCoin Was On 2014-09-26 With the Value of Over 0.000450 in  the Data of first 15 days

# %% [markdown]
# ## Q. Which day has the highest Opening and Closing Market in First 15 Days ?

# %% [markdown]
# * 2014-09-27 has highest Opening While 2014-09-26 has the highest Closing

# %%
plt.figure(figsize=(20,10))
plt.plot(doge_df_top.Date,doge_df_top.Open,marker='s',c='b',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.plot(doge_df_top.Date,doge_df_top.Close,marker='o',c='r',ls='-',lw=3,ms=12,mew=1,alpha=.5)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market Open and Close",fontsize = 30,pad=20);
plt.legend(['Open','Close','High','Low']);

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.plot(doge_df_top.Date,doge_df_top.High,marker='s',c='y',ls='-',lw=3,ms=8,mew=2,mec='orange');
plt.xlabel('Date',fontsize=25)
plt.ylabel('High',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)


plt.title("Dogecoin Market Highest",fontsize=30,pad=20);
plt.legend(['High','Date']);

# %% [markdown]
# * The Dogecoin Was its highest on 2014-09-26 With the Value of around 0.000472 in first 15 Days

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.plot(doge_df_top.Date,doge_df_top.Low)
plt.plot(doge_df_top.Date,doge_df_top.Low,marker='s',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('High',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market Lowest",fontsize=30,pad=20);
plt.legend(['High','Date']);

# %% [markdown]
# * On 2014-09-18 and On 2014-09-20 the DogeCoin Was at its lowest With the Valueof  0.00027 in first 15 days

# %%
plt.figure(figsize=(20,10))
plt.plot(doge_df_top.Date,doge_df_top.High,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.5)
plt.plot(doge_df_top.Date,doge_df_top.Low,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.5)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market High and Low",fontsize = 30,pad=20);
plt.legend(['High','Low']);

# %% [markdown]
# * From this graph We Can Conclude  that On On 2014-09-18 and On 2014-09-20 the DogeCoin Was at its lowest With the Valueof  0.00027 and Was highest on 2014-09-26 With the Value of around 0.000472 in first 15 Days

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(doge_df_top.Date,doge_df_top.Volume)
plt.plot(doge_df_top.Date,doge_df_top.Volume,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=20, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.title("Dogecoin Volume in First 15 Days",fontsize=30,pad=20);
plt.legend(['Volume','Date']);

# %% [markdown]
# * The Volume Was Highest On 2014-09-26 in the first 15 days With the Value of around 4722610.0

# %%
plt.figure(figsize=(20,10))
plt.plot(doge_df_top.Date,doge_df_top.High,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(doge_df_top.Date,doge_df_top.Low,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.9)
plt.plot(doge_df_top.Date,doge_df_top.Open,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(doge_df_top.Date,doge_df_top.Close,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
# plt.plot(final_df.Date,final_df.Volume,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market In First 15 Days",fontsize = 30,pad=20);
plt.legend(['High','Low','Open','Close']);

# %% [markdown]
# # Q2. What is the Value of Dogecoin On the Last Day of Every Year

# %% [markdown]
# * We Will Start By First Collecting The Data Of Last Day by Quering the Data from the Dataset and Make One Dataset by Appending the Data

# %%
df0=doge_df.query('Date =="2014-12-31"')
df1=doge_df.query('Date =="2015-12-31"')
df2=doge_df.query('Date =="2016-12-31"')
df3=doge_df.query('Date =="2017-12-31"')
df4=doge_df.query('Date =="2018-12-31"')
df5=doge_df.query('Date =="2019-12-31"')
df6=doge_df.query('Date =="2020-12-31"')

ds=(df0,df1,df2,df3,df4,df5,df6)
ds
# Out:
# (           Date      Open      High       Low     Close  Adj Close    Volume
#  105  2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187  314633.0,
#             Date      Open      High       Low     Close  Adj Close   Volume
#  470  2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151  95446.0,
#             Date      Open      High       Low     Close  Adj Close   Volume
#  836  2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223  73496.0,
#              Date      Open      High       Low     Close  Adj Close  \
#  1201  2017-12-31  0.007803  0.009274  0.007669  0.008972   0.008972
#
#            Volume
#  1201  62256400.0  ,
#              Date     Open      High       Low     Close  Adj Close      Volume
#  1566  2018-12-31  0.00237  0.002395  0.002325  0.002346   0.002346  18724788.0,
#              Date      Open      High       Low     Close  Adj Close  \
#  1931  2019-12-31  0.002056  0.002056  0.002022  0.002028   0.002028
#
# ...

# %%
new1=df0.append(df1)
new1
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume
# 105  2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187  314633.0
# 470  2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151   95446.0

# %%
new2=new1.append(df2)

new2
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume
# 105  2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187  314633.0
# 470  2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151   95446.0
# 836  2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223   73496.0

# %%
new3=new2.append(df3)
new3
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 105   2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187
# 470   2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151
# 836   2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223
# 1201  2017-12-31  0.007803  0.009274  0.007669  0.008972   0.008972
#
#           Volume
# 105     314633.0
# 470      95446.0
# 836      73496.0
# 1201  62256400.0

# %%
new4=new3.append(df4)
new4
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 105   2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187
# 470   2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151
# 836   2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223
# 1201  2017-12-31  0.007803  0.009274  0.007669  0.008972   0.008972
# 1566  2018-12-31  0.002370  0.002395  0.002325  0.002346   0.002346
#
#           Volume
# 105     314633.0
# 470      95446.0
# 836      73496.0
# 1201  62256400.0
# 1566  18724788.0

# %%
new5=new4.append(df5)
new5
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 105   2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187
# 470   2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151
# 836   2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223
# 1201  2017-12-31  0.007803  0.009274  0.007669  0.008972   0.008972
# 1566  2018-12-31  0.002370  0.002395  0.002325  0.002346   0.002346
# 1931  2019-12-31  0.002056  0.002056  0.002022  0.002028   0.002028
#
#           Volume
# 105     314633.0
# 470      95446.0
# 836      73496.0
# 1201  62256400.0
# 1566  18724788.0
# 1931  69469785.0

# %%
new6=new5.append(df6)
new6
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 105   2014-12-31  0.000179  0.000187  0.000178  0.000187   0.000187
# 470   2015-12-31  0.000151  0.000157  0.000147  0.000151   0.000151
# 836   2016-12-31  0.000227  0.000228  0.000223  0.000223   0.000223
# 1201  2017-12-31  0.007803  0.009274  0.007669  0.008972   0.008972
# 1566  2018-12-31  0.002370  0.002395  0.002325  0.002346   0.002346
# 1931  2019-12-31  0.002056  0.002056  0.002022  0.002028   0.002028
# 2297  2020-12-31  0.004636  0.004743  0.004553  0.004682   0.004682
#
#           Volume
# 105     314633.0
# 470      95446.0
# 836      73496.0
# 1201  62256400.0
# 1566  18724788.0
# 1931  69469785.0
# 2297  85498337.0

# %%
final_df=new6.drop(["Adj Close"],axis=1)
final_df
# Out:
#             Date      Open      High       Low     Close      Volume
# 105   2014-12-31  0.000179  0.000187  0.000178  0.000187    314633.0
# 470   2015-12-31  0.000151  0.000157  0.000147  0.000151     95446.0
# 836   2016-12-31  0.000227  0.000228  0.000223  0.000223     73496.0
# 1201  2017-12-31  0.007803  0.009274  0.007669  0.008972  62256400.0
# 1566  2018-12-31  0.002370  0.002395  0.002325  0.002346  18724788.0
# 1931  2019-12-31  0.002056  0.002056  0.002022  0.002028  69469785.0
# 2297  2020-12-31  0.004636  0.004743  0.004553  0.004682  85498337.0

# %% [markdown]
# * This is Our final Dataset Which Contain the Data of Last Day Of Year

# %% [markdown]
# # Q3. Which Year Has Highest Opening on the Last Day Of the year

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(final_df.Date,final_df.Open)
plt.plot(final_df.Date,final_df.Open,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Opening On the Last Day of Every year",fontsize=30,pad=20);
plt.legend(['Open','Date']);

# %% [markdown]
# * In 2017 the Dogecoin Has Highest Opening On the Last of the Year

# %% [markdown]
# # Q. Which Year Has Highest Closeing on the Last Day Of the year

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(final_df.Date,final_df.Close)
plt.plot(final_df.Date,final_df.Close,marker='s',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Closeing On the Last Day of Every year",fontsize=30,pad=20);
plt.legend(['Close','Date']);

# %% [markdown]
# * In 2017 the Dogecoin Has Highest Closeing On the Last of the Year

# %% [markdown]
# # Q3. Which Year Has Highest  Value on the Last Day Of the year

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(final_df.Date,final_df.High)
plt.plot(final_df.Date,final_df.High,marker='s',c='g',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Highest On the Last Day of  Every year",fontsize=30,pad=20);
plt.legend(['High','Date']);

# %% [markdown]
# * In 2017 the Dogecoin Was Highest  On the Last of the Year

# %% [markdown]
# # Q3. Which Year Has Lowest  Value on the Last Day Of the year

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(final_df.Date,final_df.Low)
plt.plot(final_df.Date,final_df.Low,marker='s',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Lowest On the Last Day of Every year",fontsize=30,pad=20);
plt.legend(['Low','Date']);

# %% [markdown]
# * In 2014 and 2015 the Dogecoin Was Lowest  On the Last of the Year

# %% [markdown]
# ##  * Conclusion

# %%
plt.figure(figsize=(20,10))
plt.plot(final_df.Date,final_df.High,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(final_df.Date,final_df.Low,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.9)
plt.plot(final_df.Date,final_df.Open,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(final_df.Date,final_df.Close,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
# plt.plot(final_df.Date,final_df.Volume,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market On the Last Day of Every Year",fontsize = 30,pad=20);
plt.legend(['High','Low','Open','Close']);

# %% [markdown]
#  * From Graph We Conclude that On the Last Day of Year 2017 Went Well For Dogecoin Because in this year,Dogecoin Has highest Opening Highest Closeing Has Highest Value

# %% [markdown]
# # Q. Which year Has Highest Volume Of Dogecoin on the Last of Year ?

# %%
plt.figure(figsize=(20,10))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(final_df.Date,final_df.Volume)
plt.plot(final_df.Date,final_df.Volume,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Volume On the Last Day of Every year",fontsize=30,pad=20);
plt.legend(['Volume','Date']);

# %% [markdown]
# * Year 2020 Has Highest Volume of Dogecoin On the Last Day of year

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = 'Date',  y ='Volume', data = final_df);
plt.title("Dogecoin Volume On the Last Day of Every year",fontsize=30,pad=20);
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.plot(final_df.Date,final_df.Volume,marker='o',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy',alpha=.7);

# %% [markdown]
# # Q. Compare the Performance of Dogecoin On  the First and Last Day of Dataset

# %% [markdown]
#  * We Start With making new Dataset by taking the  Data of First and Last row

# %%
df0=doge_df.query('Date =="2014-09-17"')
df1=doge_df.query('Date =="2021-06-05"')
df0,df1
# Out:
# (         Date      Open      High      Low     Close  Adj Close     Volume
#  0  2014-09-17  0.000293  0.000299  0.00026  0.000268   0.000268  1463600.0,
#              Date      Open      High       Low     Close  Adj Close  \
#  2453  2021-06-05  0.373712  0.389095  0.373712  0.383337   0.383337
#
#              Volume
#  2453  4.957235e+09  )

# %%
first_df=df0.append(df1)
first_df
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2014-09-17  0.000293  0.000299  0.000260  0.000268   0.000268
# 2453  2021-06-05  0.373712  0.389095  0.373712  0.383337   0.383337
#
#             Volume
# 0     1.463600e+06
# 2453  4.957235e+09

# %%
first_df=df0.append(df1)
first_df
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2014-09-17  0.000293  0.000299  0.000260  0.000268   0.000268
# 2453  2021-06-05  0.373712  0.389095  0.373712  0.383337   0.383337
#
#             Volume
# 0     1.463600e+06
# 2453  4.957235e+09

# %% [markdown]
# # Q. By How much Volume Increase from Day1 to Last Day ?

# %%
plt.figure(figsize=(14,8))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(first_df.Date,first_df.Volume)
plt.plot(first_df.Date,first_df.Volume,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("DogeCoin Volume On First and Last Day",fontsize=25,pad=20);
plt.legend(['Volume','Date']);

# %% [markdown]
#  * The Dogecoin Was increase by  4955771400 Volume  by 2021-06-05

# %% [markdown]
# # Q. By How much Opening Increase from Day1 to Last Day ?

# %%
plt.figure(figsize=(14,8))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(first_df.Date,first_df.Open)
plt.plot(first_df.Date,first_df.Open,marker='x',ls='--',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Opening On First and Last Day",fontsize=25,pad=20);
plt.legend(['Open','Date']);

# %% [markdown]
# * The Opening Was increase by 0.373419

# %%
plt.figure(figsize=(10,6))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(first_df.Date,first_df.Close)
plt.plot(first_df.Date,first_df.Close,marker='o',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Closeing On First and Last Day",fontsize=25,pad=20);
plt.legend(['Close','Date']);

# %%
plt.figure(figsize=(10,6))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(first_df.Date,first_df.High)
# sns.barplot(x = 'Date',  y ='Volume', data = first_df);
plt.plot(first_df.Date,first_df.High,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Highest On First and Last Day",fontsize=25,pad=20);
plt.legend(['High','Date']);

# %%
plt.figure(figsize=(10,6))
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.4)
plt.plot(first_df.Date,first_df.Low)
plt.plot(first_df.Date,first_df.Low,marker='s',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize=25)
plt.ylabel('USD',fontsize=25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Lowest On First and Last Day",fontsize=25,pad=20);
plt.legend(['Low','Date']);

# %%
plt.figure(figsize=(20,10))
plt.plot(first_df.Date,first_df.High,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(first_df.Date,first_df.Low,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.9)
plt.plot(first_df.Date,first_df.Open,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(first_df.Date,first_df.Close,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
# plt.plot(final_df.Date,final_df.Volume,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=0)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market On First and Last Day",fontsize = 30,pad=20);
plt.legend(['High','Low','Open','Close']);

# %%
tail1_df=doge_df.tail(20)
tail1_df
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 2434  2021-05-17  0.513413  0.515221  0.458551  0.487892   0.487892
# 2435  2021-05-18  0.486954  0.515599  0.470384  0.476115   0.476115
# 2436  2021-05-19  0.476435  0.684735  0.218267  0.333123   0.333123
# 2437  2021-05-20  0.330252  0.433192  0.296253  0.400194   0.400194
# 2438  2021-05-21  0.398124  0.411975  0.314766  0.359382   0.359382
# 2439  2021-05-22  0.358717  0.360517  0.318169  0.342371   0.342371
# 2440  2021-05-23  0.342522  0.350863  0.249437  0.308071   0.308071
# 2441  2021-05-24  0.306715  0.371485  0.296291  0.366162   0.366162
# 2442  2021-05-25  0.366041  0.380010  0.323497  0.346302   0.346302
# 2443  2021-05-26  0.346396  0.365920  0.338857  0.353693   0.353693
# 2444  2021-05-27  0.353463  0.353463  0.328144  0.332945   0.332945
# 2445  2021-05-28  0.333651  0.347879  0.301518  0.311205   0.311205
# 2446  2021-05-29  0.311398  0.317919  0.281793  0.303110   0.303110
# ...

# %%
tail_df=tail1_df.drop(['Adj Close'],axis=1)
tail_df
# Out:
#             Date      Open      High       Low     Close        Volume
# 2434  2021-05-17  0.513413  0.515221  0.458551  0.487892  7.330831e+09
# 2435  2021-05-18  0.486954  0.515599  0.470384  0.476115  4.802903e+09
# 2436  2021-05-19  0.476435  0.684735  0.218267  0.333123  1.507262e+10
# 2437  2021-05-20  0.330252  0.433192  0.296253  0.400194  1.241548e+10
# 2438  2021-05-21  0.398124  0.411975  0.314766  0.359382  7.452862e+09
# 2439  2021-05-22  0.358717  0.360517  0.318169  0.342371  5.243222e+09
# 2440  2021-05-23  0.342522  0.350863  0.249437  0.308071  7.143545e+09
# 2441  2021-05-24  0.306715  0.371485  0.296291  0.366162  6.821089e+09
# 2442  2021-05-25  0.366041  0.380010  0.323497  0.346302  5.544553e+09
# 2443  2021-05-26  0.346396  0.365920  0.338857  0.353693  3.355793e+09
# 2444  2021-05-27  0.353463  0.353463  0.328144  0.332945  2.485942e+09
# 2445  2021-05-28  0.333651  0.347879  0.301518  0.311205  3.289456e+09
# ...

# %% [markdown]
# # Q. What Was the Opening Of Dogecoin Market in Past 1 Months?

# %%
plt.figure(figsize=(20,12))
plt.plot(tail_df.Date,tail_df.Open,marker='s',c='b',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['Open','Date']);

# %% [markdown]
# # Q. What Was the Closeing Of Dogecoin Market in Past 1 Months?

# %%
plt.figure(figsize=(20,12))
plt.plot(tail_df.Date,tail_df.Close,marker='s',c='g',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['Close','Date']);

# %% [markdown]
# # Q. What Was the Highest Of Dogecoin Market in Past 1 Months?

# %%
plt.figure(figsize=(20,12))
plt.plot(tail_df.Date,tail_df.High,marker='s',c='y',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin  Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['High','Date']);

# %% [markdown]
# # Q. What Was the Lowest Of Dogecoin Market in Past 1 Months?

# %%
plt.figure(figsize=(20,12))
plt.plot(tail_df.Date,tail_df.Low,marker='s',c='r',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin  Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['Low','Date']);

# %% [markdown]
# # Q. What Was the Volume Of Dogecoin Market in Past 1 Months?

# %%
plt.figure(figsize=(20,12))
plt.plot(tail_df.Date,tail_df.Volume,marker='s',ls='-',lw=3,ms=8,mew=2,mec='navy');
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Volume Market  ",fontsize=30, pad=20);
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.legend(['Volume','Date']);

# %%
plt.figure(figsize=(20,10))
plt.plot(tail_df.Date,tail_df.High,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(tail_df.Date,tail_df.Low,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.9)
plt.plot(tail_df.Date,tail_df.Open,marker='o',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.plot(tail_df.Date,tail_df.Close,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
# plt.plot(final_df.Date,final_df.Volume,marker='d',ls='-',lw=3,ms=12,mew=1,alpha=.7)
plt.xlabel('Date',fontsize = 25)
plt.ylabel('USD',fontsize = 25)
plt.grid(color='g', linestyle='-', linewidth=0.8,alpha=0.5)
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.title("Dogecoin Market",fontsize = 30,pad=20);
plt.legend(['High','Low','Open','Close','Volume']);

# %%
# Out:
#   File "<ipython-input-177-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
